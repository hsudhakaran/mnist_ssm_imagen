# %%
import jax
import jax.numpy as jnp
from flax import linen as nn
import optax
from typing import Callable, Tuple, Any
import numpy as np
from functools import partial
import pdb
import tensorflow as tf

import matplotlib.pyplot as plt
import seaborn

# %%
# Load the MNIST dataset
(X_train, Y_train), (X_test, Y_test) = tf.keras.datasets.mnist.load_data()
X_train, Y_train, X_test, Y_test = jnp.expand_dims(jnp.array(X_train/255), axis=-1), jnp.expand_dims(jnp.array(Y_train), axis=-1), jnp.expand_dims(jnp.array(X_test/255), axis=-1), jnp.expand_dims(jnp.array(Y_test), axis=-1)

# %%
Y_train.shape
# Out:
# (60000, 1)

# %%
@jax.jit
def get_sample_and_label(idx, inputs, labels):
    return inputs[idx], labels[idx]

arr = jnp.array([32,67,432,2])
xb, yb = jax.vmap(get_sample_and_label, in_axes=(0,None,None))(arr, X_train, Y_train)
xb.shape, yb.shape
# Out:
# ((4, 28, 28, 1), (4, 1))

# %%
class S6_Unet(nn.Module):
    embed_dim: int = 64
    n_latent_dim: int = 8

    @nn.compact
    def __call__(self, x, h=0):
        # x.shape = (Ba, n_filters, seq_size, hidden_dim)
        _, seq_size , hidden_dim = x.shape
        Ba = x.shape[0]
        A = -1* self.param('A', nn.initializers.ones, (1,  self.n_latent_dim, self.embed_dim , self.embed_dim))
        B = self.param('B', nn.initializers.ones, (1,  self.n_latent_dim, 1, self.embed_dim))
        C = self.param('C', jax.random.normal, (1,  self.n_latent_dim, self.embed_dim, 1))
        D = self.param('D', jax.random.normal, (1,  self.n_latent_dim, hidden_dim, 1))
        S = -0.5* self.param('S', nn.initializers.ones, (1,  self.n_latent_dim, 1, self.embed_dim))
        h = h*jnp.ones((Ba,  self.n_latent_dim, hidden_dim, self.embed_dim))
        x = self.ssm(x, A, B, C, D, S, h)
        return x
    def ssm(self, x, A, B, C, D, S, h):
        def compute_delta(x, state, A, B):
            # state shape: (B, N, D)
            # A shape: (N, N)
            # B shape: (N, D)

            # State update: (B, N, D, H) <- (B, N, D, H) @ (1, N, H, H)
            state_contribution = nn.RMSNorm()(state@A) #jnp.einsum('bnd,nn->bnd', state, A)
            # Input contribution: (B, N, D, H) <- (B, 1, D, 1) @ (1, N, 1, H)
            input_contribution = x@B
            # print("state_contribution + input_contribution: ", state_contribution.sum(), input_contribution.sum())
            return state_contribution + input_contribution

        for k in range(x.shape[1]):
            # Compute ∆, the state update candidates
#             pdb.set_trace()
            # print("k: ", k)
            delta = compute_delta(jnp.expand_dims(x[:,k,:], axis=(1,3)), h, A, B)
            #h: (B, N, D, H) <- (B, N, D, H)*(B, 1, D, 1)*(1, N, 1, H)
            h += delta*jnp.expand_dims(x[:,k,:], axis=(1,3))*S
            # print("h sum:", h.min(), h.max(), jnp.sum(h))
        # pdb.set_trace()
        #y: (B, N, D, 1) <- (B, N, D, H) @ (1, N, H, 1) + (B, 1, D, 1)*(1, N, D, 1)
        y = h @ C + jnp.expand_dims(x[:,-1,:], axis=(1,3))*D
        return jnp.einsum('bnd1->b1d', y)

# %%
class VisionEncoder(nn.Module):
    embed_dim: int = 64
    patch_size: int = 2
    hidden_dim: int = 32

    @nn.compact
    def __call__(self, x):
        # Assuming input shape: (batch, height, width, channels)
        # Patch embedding

########################################################################################################################################

        for i in range(3):
            x = nn.Conv(
                features=self.hidden_dim*(2**i),
                kernel_size=(self.patch_size, self.patch_size),
                strides=(1, 1)
                )(x)

            x = nn.max_pool(x, window_shape=(self.patch_size, self.patch_size), strides=(self.patch_size, self.patch_size))

        print("After conv", x.shape)
        x = x.reshape(x.shape[0], -1, x.shape[-1])
        print("After reshape",x.shape)
        x = S6_Unet()(jax.nn.silu(nn.RMSNorm()(x)))
        print("After S6", x.shape)

        return nn.Dense(10)(x)
########################################################################################################################################



########################################################################################################################################
        # x = jax.nn.silu(nn.Conv(features=64, kernel_size=(self.patch_size, self.patch_size))(x))
        # print("After first conv: ", x.shape)
        # x = nn.max_pool(x, window_shape=(2, 2), strides=(self.patch_size, self.patch_size))
        # print("After first max pool: ", x.shape)
        # x = jax.nn.silu(nn.Conv(features=128, kernel_size=(self.patch_size, self.patch_size))(x))
        # print("After 2nd conv: ", x.shape)
        # x = nn.max_pool(x, window_shape=(2, 2), strides=(self.patch_size, self.patch_size))
        # print("After 2nd max pool: ", x.shape)
        # x = jax.nn.silu(nn.Conv(features=256, kernel_size=(self.patch_size, self.patch_size))(x))
        # print("After 3rd conv: ", x.shape)
        # x = x.reshape(x.shape[0], -1)  # flatten
        # print("After flatten: ", x.shape)
        # x = jax.nn.silu(nn.Dense(256)(x))
########################################################################################################################################

########################################################################################################################################
        # # Flatten patches
        # x =x.reshape(x.shape[0], -1, x.shape[-1])

        # # Transformer blocks
        # for _ in range(6):  # 6 layers
        #     x = nn.MultiHeadDotProductAttention(
        #         num_heads=8,
        #         qkv_features=self.hidden_dim
        #     )(x)
        #     x = nn.LayerNorm()(x)

        # # Projection to embedding dimension
        # x = jax.nn.silu(nn.Dense(self.embed_dim)(jax.nn.silu(x.mean(axis=1))))
########################################################################################################################################

        # x = nn.Dense(10)(x)
        # return jnp.expand_dims(x, axis=1)

model = VisionEncoder()
params = model.init(jax.random.PRNGKey(451),jnp.ones((1,28,28,1)))
n_params = sum(p.size for p in jax.tree_util.tree_leaves(params))
print(f"Total number of parameters: {n_params:_}")
# Out:
# After conv (1, 3, 3, 128)
# After reshape (1, 9, 128)
# After S6 (1, 1, 128)
# Total number of parameters: 78_634

# %%
model.apply(params,jnp.ones((1,28,28,1))).shape
# Out:
# After conv (1, 3, 3, 128)
# After reshape (1, 9, 128)
# After S6 (1, 1, 128)
# (1, 1, 10)

# %%
# opt = optax.sgd(learning_rate, momentum)
opt = optax.adamw(learning_rate=0.001)


opt_state = opt.init(params)

# %%
def loss_fun(params, x, y):
    logits = model.apply(params, x)
    accuracy = jnp.mean(jnp.argmax(logits, axis=-1) == y)
    return optax.softmax_cross_entropy_with_integer_labels(logits=logits, labels=y).mean(), accuracy

@jax.jit
def eval_step(params, x, y):
    logits = model.apply(params, x)
    accuracy = jnp.mean(jnp.argmax(logits, axis=-1) == y)
    return optax.softmax_cross_entropy_with_integer_labels(logits=logits, labels=y).mean(), accuracy

# %%
# %%time
key = jax.random.PRNGKey(42)  # Replace 42 with any random seed
BATCH_SIZE = 64
learning_rate = 0.1
momentum = 0.9
train_length = len(X_train)//BATCH_SIZE
kernel_s = 2
eval_iters = 1000

all_train_losses = []
all_eval_losses = []

all_train_accuracy =  []
all_test_accuracy = []

eval_iters = 50000

@jax.jit
def step(idx, params, opt_state):
    xb, yb = jax.vmap(get_sample_and_label, in_axes=(0,None,None))(idx, X_train, Y_train)
    (loss, train_accuracy), grad = jax.value_and_grad(loss_fun, has_aux=True)(params, xb, yb)
    updates, opt_state = opt.update(grad, opt_state, params)
    params = optax.apply_updates(params, updates)
    return params, opt_state, loss, train_accuracy

for i in range(eval_iters):
    key, subkey = jax.random.split(key)
    iix = jax.random.randint(subkey, shape=(BATCH_SIZE,), minval=0, maxval=len(X_train))
    params, opt_state, loss, train_accuracy = step(iix, params, opt_state)

    # once every N_FREQ_EVAL we compute loss on the validation set
    if i%100 == 0:
        key, subkey = jax.random.split(key)
        indxs = jax.random.randint(subkey, shape=(BATCH_SIZE,), minval=0, maxval=len(X_test))
        xt, yt = jax.vmap(get_sample_and_label, in_axes=(0,None,None))(indxs, X_test, Y_test)
        eval_loss, eval_accuracy = eval_step(params, xt, yt)
        all_train_losses.append(loss)
        all_eval_losses.append(eval_loss)
        all_train_accuracy.append(train_accuracy)
        all_test_accuracy.append(eval_accuracy)
        print('####################################################################################################')
        print("Step: ", i,"\t\t Train Loss: ", format(loss, ".6f"),"\t\t Train Accuracy: ", format(train_accuracy, ".2%"))
        print("Step: ", i,"\t\t Eval Loss: ", format(eval_loss, ".6f"),"\t\t Eval Accuracy: ", format(eval_accuracy, ".2%"))
# Out:
# After conv (64, 3, 3, 128)
# After reshape (64, 9, 128)
# After S6 (64, 1, 128)
# After conv (64, 3, 3, 128)
# After reshape (64, 9, 128)
# After S6 (64, 1, 128)
# ####################################################################################################
# Step:  0 		 Train Loss:  626.939819 		 Train Accuracy:  3.12%
# Step:  0 		 Eval Loss:  418.483856 		 Eval Accuracy:  4.69%
# ####################################################################################################
# Step:  100 		 Train Loss:  1.832799 		 Train Accuracy:  34.38%
# Step:  100 		 Eval Loss:  1.944350 		 Eval Accuracy:  40.62%
# ####################################################################################################
# Step:  200 		 Train Loss:  2.074398 		 Train Accuracy:  29.69%
# Step:  200 		 Eval Loss:  2.050316 		 Eval Accuracy:  28.12%
# ####################################################################################################
# Step:  300 		 Train Loss:  2.727752 		 Train Accuracy:  15.62%
# Step:  300 		 Eval Loss:  2.414381 		 Eval Accuracy:  23.44%
# ####################################################################################################
# Step:  400 		 Train Loss:  2.230688 		 Train Accuracy:  23.44%
# Step:  400 		 Eval Loss:  2.305115 		 Eval Accuracy:  21.88%
# ####################################################################################################
# Step:  500 		 Train Loss:  1.901318 		 Train Accuracy:  26.56%
# Step:  500 		 Eval Loss:  2.109137 		 Eval Accuracy:  23.44%
# ####################################################################################################
# Step:  600 		 Train Loss:  1.685053 		 Train Accuracy:  45.31%
# Step:  600 		 Eval Loss:  1.761662 		 Eval Accuracy:  31.25%
# ####################################################################################################
# Step:  700 		 Train Loss:  1.793990 		 Train Accuracy:  31.25%
# Step:  700 		 Eval Loss:  1.601836 		 Eval Accuracy:  40.62%
# ####################################################################################################
# Step:  800 		 Train Loss:  1.800889 		 Train Accuracy:  35.94%
# Step:  800 		 Eval Loss:  1.657315 		 Eval Accuracy:  46.88%
# ####################################################################################################
# Step:  900 		 Train Loss:  1.686675 		 Train Accuracy:  43.75%
# Step:  900 		 Eval Loss:  1.641870 		 Eval Accuracy:  37.50%
# ####################################################################################################
# Step:  1000 		 Train Loss:  1.683143 		 Train Accuracy:  40.62%
# Step:  1000 		 Eval Loss:  1.745950 		 Eval Accuracy:  37.50%
# ####################################################################################################
# Step:  1100 		 Train Loss:  1.523429 		 Train Accuracy:  40.62%
# Step:  1100 		 Eval Loss:  1.485126 		 Eval Accuracy:  46.88%
# ####################################################################################################
# Step:  1200 		 Train Loss:  1.590003 		 Train Accuracy:  45.31%
# Step:  1200 		 Eval Loss:  1.663402 		 Eval Accuracy:  46.88%
# ####################################################################################################
# Step:  1300 		 Train Loss:  1.679544 		 Train Accuracy:  42.19%
# Step:  1300 		 Eval Loss:  1.638261 		 Eval Accuracy:  37.50%
# ####################################################################################################
# Step:  1400 		 Train Loss:  1.353847 		 Train Accuracy:  51.56%
# Step:  1400 		 Eval Loss:  1.329515 		 Eval Accuracy:  51.56%
# ####################################################################################################
# Step:  1500 		 Train Loss:  1.438239 		 Train Accuracy:  48.44%
# Step:  1500 		 Eval Loss:  1.453326 		 Eval Accuracy:  45.31%
# ####################################################################################################
# Step:  1600 		 Train Loss:  1.532255 		 Train Accuracy:  37.50%
# Step:  1600 		 Eval Loss:  1.617420 		 Eval Accuracy:  34.38%
# ####################################################################################################
# Step:  1700 		 Train Loss:  1.391833 		 Train Accuracy:  53.12%
# Step:  1700 		 Eval Loss:  1.409711 		 Eval Accuracy:  43.75%
# ####################################################################################################
# Step:  1800 		 Train Loss:  1.407206 		 Train Accuracy:  54.69%
# Step:  1800 		 Eval Loss:  1.397169 		 Eval Accuracy:  46.88%
# ####################################################################################################
# Step:  1900 		 Train Loss:  1.277605 		 Train Accuracy:  56.25%
# Step:  1900 		 Eval Loss:  1.258236 		 Eval Accuracy:  53.12%
# ####################################################################################################
# Step:  2000 		 Train Loss:  1.153709 		 Train Accuracy:  53.12%
# Step:  2000 		 Eval Loss:  1.170119 		 Eval Accuracy:  59.38%
# ####################################################################################################
# Step:  2100 		 Train Loss:  1.407331 		 Train Accuracy:  50.00%
# Step:  2100 		 Eval Loss:  1.438185 		 Eval Accuracy:  48.44%
# ####################################################################################################
# Step:  2200 		 Train Loss:  1.288364 		 Train Accuracy:  59.38%
		 Eval Accuracy:  78.12%
# ####################################################################################################
# Step:  5800 		 Train Loss:  0.959613 		 Train Accuracy:  70.31%
# Step:  5800 		 Eval Loss:  1.162813 		 Eval Accuracy:  65.62%
# ####################################################################################################
# Step:  5900 		 Train Loss:  1.079212 		 Train Accuracy:  60.94%
# Step:  5900 		 Eval Loss:  0.891464 		 Eval Accuracy:  65.62%
# ####################################################################################################
# Step:  6000 		 Train Loss:  0.900153 		 Train Accuracy:  70.31%
# Step:  6000 		 Eval Loss:  0.921107 		 Eval Accuracy:  67.19%
# ####################################################################################################
# Step:  6100 		 Train Loss:  1.187363 		 Train Accuracy:  59.38%
# Step:  6100 		 Eval Loss:  0.869726 		 Eval Accuracy:  65.62%
# ####################################################################################################
# Step:  6200 		 Train Loss:  0.849207 		 Train Accuracy:  71.88%
# Step:  6200 		 Eval Loss:  0.767963 		 Eval Accuracy:  78.12%
# ####################################################################################################
# Step:  6300 		 Train Loss:  0.716765 		 Train Accuracy:  78.12%
# Step:  6300 		 Eval Loss:  0.887626 		 Eval Accuracy:  67.19%
# ####################################################################################################
# Step:  6400 		 Train Loss:  0.851332 		 Train Accuracy:  68.75%
# Step:  6400 		 Eval Loss:  0.826638 		 Eval Accuracy:  70.31%
# ####################################################################################################
# Step:  6500 		 Train Loss:  0.906264 		 Train Accuracy:  71.88%
# Step:  6500 		 Eval Loss:  0.973103 		 Eval Accuracy:  64.06%
# ####################################################################################################
# Step:  6600 		 Train Loss:  1.095066 		 Train Accuracy:  70.31%
# Step:  6600 		 Eval Loss:  0.908842 		 Eval Accuracy:  60.94%
# ####################################################################################################
# Step:  6700 		 Train Loss:  1.083085 		 Train Accuracy:  67.19%
# Step:  6700 		 Eval Loss:  0.728195 		 Eval Accuracy:  78.12%
# ####################################################################################################
# Step:  6800 		 Train Loss:  0.910109 		 Train Accuracy:  71.88%
# Step:  6800 		 Eval Loss:  0.799627 		 Eval Accuracy:  71.88%
# ####################################################################################################
# Step:  6900 		 Train Loss:  0.881717 		 Train Accuracy:  73.44%
# Step:  6900 		 Eval Loss:  0.864974 		 Eval Accuracy:  73.44%
# ####################################################################################################
# Step:  7000 		 Train Loss:  0.839486 		 Train Accuracy:  73.44%
# Step:  7000 		 Eval Loss:  0.955283 		 Eval Accuracy:  68.75%
# ####################################################################################################
# Step:  7100 		 Train Loss:  0.671744 		 Train Accuracy:  82.81%
# Step:  7100 		 Eval Loss:  0.679429 		 Eval Accuracy:  79.69%
# ####################################################################################################
# Step:  7200 		 Train Loss:  0.911903 		 Train Accuracy:  65.62%
# Step:  7200 		 Eval Loss:  0.696657 		 Eval Accuracy:  73.44%
# ####################################################################################################
# Step:  7300 		 Train Loss:  0.796019 		 Train Accuracy:  71.88%
# Step:  7300 		 Eval Loss:  0.868995 		 Eval Accuracy:  75.00%
# ####################################################################################################
# Step:  7400 		 Train Loss:  1.034318 		 Train Accuracy:  62.50%
# Step:  7400 		 Eval Loss:  0.866198 		 Eval Accuracy:  79.69%
# ####################################################################################################
# Step:
		 Eval Accuracy:  92.19%
# ####################################################################################################
# Step:  45000 		 Train Loss:  0.220761 		 Train Accuracy:  90.62%
# Step:  45000 		 Eval Loss:  0.237606 		 Eval Accuracy:  92.19%
# ####################################################################################################
# Step:  45100 		 Train Loss:  0.264723 		 Train Accuracy:  90.62%
# Step:  45100 		 Eval Loss:  0.145214 		 Eval Accuracy:  95.31%
# ####################################################################################################
# Step:  45200 		 Train Loss:  0.422627 		 Train Accuracy:  89.06%
# Step:  45200 		 Eval Loss:  0.159221 		 Eval Accuracy:  96.88%
# ####################################################################################################
# Step:  45300 		 Train Loss:  0.162861 		 Train Accuracy:  95.31%
# Step:  45300 		 Eval Loss:  0.350243 		 Eval Accuracy:  87.50%
# ####################################################################################################
# Step:  45400 		 Train Loss:  0.557156 		 Train Accuracy:  79.69%
# Step:  45400 		 Eval Loss:  0.102004 		 Eval Accuracy:  96.88%
# ####################################################################################################
# Step:  45500 		 Train Loss:  0.491704 		 Train Accuracy:  82.81%
# Step:  45500 		 Eval Loss:  0.281502 		 Eval Accuracy:  92.19%
# ####################################################################################################
# Step:  45600 		 Train Loss:  0.260756 		 Train Accuracy:  89.06%
# Step:  45600 		 Eval Loss:  0.122710 		 Eval Accuracy:  96.88%
# ####################################################################################################
# Step:  45700 		 Train Loss:  0.091171 		 Train Accuracy:  96.88%
# Step:  45700 		 Eval Loss:  0.362603 		 Eval Accuracy:  92.19%
# ####################################################################################################
# Step:  45800 		 Train Loss:  0.291745 		 Train Accuracy:  89.06%
# Step:  45800 		 Eval Loss:  0.185535 		 Eval Accuracy:  92.19%
# ####################################################################################################
# Step:  45900 		 Train Loss:  0.184468 		 Train Accuracy:  92.19%
# Step:  45900 		 Eval Loss:  0.178723 		 Eval Accuracy:  93.75%
# ####################################################################################################
# Step:  46000 		 Train Loss:  0.217650 		 Train Accuracy:  90.62%
# Step:  46000 		 Eval Loss:  0.102194 		 Eval Accuracy:  96.88%
# ####################################################################################################
# Step:  46100 		 Train Loss:  0.266374 		 Train Accuracy:  93.75%
# Step:  46100 		 Eval Loss:  0.137003 		 Eval Accuracy:  93.75%
# ####################################################################################################
# Step:  46200 		 Train Loss:  0.405681 		 Train Accuracy:  92.19%
# Step:  46200 		 Eval Loss:  0.156022 		 Eval Accuracy:  92.19%
# ####################################################################################################
# Step:  46300 		 Train Loss:  0.173747 		 Train Accuracy:  93.75%
# Step:  46300 		 Eval Loss:  0.283688 		 Eval Accuracy:  95.31%
# ####################################################################################################
# Step:  46400 		 Train Loss:  0.227104 		 Train Accuracy:  95.31%
# Step:  46400 		 Eval Loss:  0.159135 		 Eval Accuracy:  95.31%
# ####################################################################################################
# Step:  46500 		 Train Loss:  0.405235 		 Train Accuracy:  89.06%
# Step:  46500 		 Eval Loss:  0.200661 		 Eval Accuracy:  92.19%
# ####################################################################################################
# Step:  46600 		 Train Loss:  0.297103 		 Train Accuracy:  90.62%
# Step:  46600 		 Eval Loss:  0.135834 		 Eval Accuracy:  96.88%
# ####################################################################################################
# Step:  46700 		 Train Loss:  0.144244 		 Train Accuracy:  93.75%
# Step:  46700 		 Eval Loss:  0.229252 		 Eval Accuracy:  92.19%
# ####################################################################################################
# Step:  46800 		 Train Loss:  0.103112 		 Train Accuracy:  96.88%
# Step:  46800 		 Eval Loss:  0.214463 		 Eval Accuracy:  93.75%
# ####################################################################################################
# Step:  46900 		 Train Loss:  0.263218 		 Train Accuracy:  92.19%
# Step:  46900 		 Eval Loss:  0.328864 		 Eval Accuracy:  92.19%
# ####################################################################################################
# Step:  47000 		 Train Loss:  0.319522 		 Train Accuracy:  89.06%
# Step:  47000 		 Eval Loss:  0.281859 		 Eval Accuracy:  87.50%
# ####################################################################################################
# Step:  47100 		 Train Loss:  0.388135 		 Train Accuracy:  87.50%
# Step:  47100 		 Eval Loss:  0.172224 		 Eval Accuracy:  93.75%
# ####################################################################################################
# Step:  47200 		 Train Loss:  0.244943 		 Train Accuracy:  93.75%
# Step:  47200 		 Eval Loss:  0.066411 		 Eval Accuracy:  100.00%
# ####################################################################################################
# Step:  47300 		 Train Loss:  0.209533 		 Train Accuracy:  95.31%
# Step:  47300 		 Eval Loss:  0.294976 		 Eval Accuracy:  92.19%
# ####################################################################################################
# Step:  47400 		 Train Loss:  0.158525 		 Train Accuracy:  93.75%
# Step:  47400 		 Eval Loss:  0.095255 		 Eval Accuracy:  96.88%
# ####################################################################################################
# Step:  47500 		 Train Loss:  0.147623 		 Train Accuracy:  93.75%
# Step:  47500 		 Eval Loss:  0.239390 		 Eval Accuracy:  90.62%
# ####################################################################################################
# Step:  47600 		 Train Loss:  0.129133 		 Train Accuracy:  95.31%
# Step:  47600 		 Eval Loss:  0.170597 		 Eval Accuracy:  95.31%
# ####################################################################################################
# Step:  47700 		 Train Loss:  0.067328 		 Train Accuracy:  100.00%
# Step:  47700 		 Eval Loss:  0.154582 		 Eval Accuracy:  93.75%
# ####################################################################################################
# Step:  47800 		 Train Loss:  0.231750 		 Train Accuracy:  92.19%
# Step:  47800 		 Eval Loss:  0.342689 		 Eval Accuracy:  92.19%
# ####################################################################################################
# Step:  47900 		 Train Loss:  0.266484 		 Train Accuracy:  92.19%
# Step:  47900 		 Eval Loss:  0.292517 		 Eval Accuracy:  87.50%
# ####################################################################################################
# Step:  48000 		 Train Loss:  0.660262 		 Train Accuracy:  87.50%
# Step:  48000 		 Eval Loss:  0.238185 		 Eval Accuracy:  92.19%
# ####################################################################################################
# Step:  48100 		 Train Loss:  0.243351 		 Train Accuracy:  92.19%
# Step:  48100 		 Eval Loss:  0.112884 		 Eval Accuracy:  98.44%
# ####################################################################################################
# Step:  48200 		 Train Loss:  0.232330 		 Train Accuracy:  93.75%
# Step:  48200 		 Eval Loss:  0.175877 		 Eval Accuracy:  92.19%
# ####################################################################################################
# Step:  48300 		 Train Loss:  0.094393 		 Train Accuracy:  98.44%
# Step:  48300 		 Eval Loss:  0.174155 		 Eval Accuracy:  93.75%
# ####################################################################################################
# Step:  48400 		 Train Loss:  0.447609 		 Train Accuracy:  87.50%
# Step:  48400 		 Eval Loss:  0.063440 		 Eval Accuracy:  98.44%
# ####################################################################################################
# Step:  48500 		 Train Loss:  0.055590 		 Train Accuracy:  98.44%
# Step:  48500 		 Eval Loss:  0.058283 		 Eval Accuracy:  98.44%
# ####################################################################################################
# Step:  48600 		 Train Loss:  0.268232 		 Train Accuracy:  93.75%
# Step:  48600 		 Eval Loss:  0.338927 		 Eval Accuracy:  93.75%
# ####################################################################################################
# Step:  48700 		 Train Loss:  0.354734 		 Train Accuracy:  89.06%
# Step:  48700 		 Eval Loss:  0.235335 		 Eval Accuracy:  93.75%
# ####################################################################################################
# Step:  48800 		 Train Loss:  0.387294 		 Train Accuracy:  92.19%
# Step:  48800 		 Eval Loss:  0.229972 		 Eval Accuracy:  95.31%
# ####################################################################################################
# Step:  48900 		 Train Loss:  0.581561 		 Train Accuracy:  84.38%
# Step:  48900 		 Eval Loss:  0.293320 		 Eval Accuracy:  93.75%
# ####################################################################################################
# Step:  49000 		 Train Loss:  0.156677 		 Train Accuracy:  98.44%
# Step:  49000 		 Eval Loss:  0.286042 		 Eval Accuracy:  93.75%
# ####################################################################################################
# Step:  49100 		 Train Loss:  0.401729 		 Train Accuracy:  89.06%
# Step:  49100 		 Eval Loss:  0.304077 		 Eval Accuracy:  90.62%
# ####################################################################################################
# Step:  49200 		 Train Loss:  0.202780 		 Train Accuracy:  92.19%
# Step:  49200 		 Eval Loss:  0.080867 		 Eval Accuracy:  98.44%
# ####################################################################################################
# Step:  49300 		 Train Loss:  0.339119 		 Train Accuracy:  89.06%
# Step:  49300 		 Eval Loss:  0.312395 		 Eval Accuracy:  89.06%
# ####################################################################################################
# Step:  49400 		 Train Loss:  0.191509 		 Train Accuracy:  90.62%
# Step:  49400 		 Eval Loss:  0.171701 		 Eval Accuracy:  96.88%
# ####################################################################################################
# Step:  49500 		 Train Loss:  0.310431 		 Train Accuracy:  90.62%
# Step:  49500 		 Eval Loss:  0.400525 		 Eval Accuracy:  85.94%
# ####################################################################################################
# Step:  49600 		 Train Loss:  0.170421 		 Train Accuracy:  93.75%
# Step:  49600 		 Eval Loss:  0.384303 		 Eval Accuracy:  89.06%
# ####################################################################################################
# Step:  49700 		 Train Loss:  0.219492 		 Train Accuracy:  92.19%
# Step:  49700 		 Eval Loss:  0.188987 		 Eval Accuracy:  93.75%
# ####################################################################################################
# Step:  49800 		 Train Loss:  0.353288 		 Train Accuracy:  89.06%
# Step:  49800 		 Eval Loss:  0.348324 		 Eval Accuracy:  90.62%
# ####################################################################################################
# Step:  49900 		 Train Loss:  0.193297 		 Train Accuracy:  96.88%
# Step:  49900 		 Eval Loss:  0.307166 		 Eval Accuracy:  87.50%
# CPU times: user 2min 55s, sys: 11.6 s, total: 3min 6s
# Wall time: 18min 44s

# %%
# Plot loss and accuracy in subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
ax1.set_title('Loss')
ax2.set_title('Accuracy')



ax1.plot(all_train_losses, label='train_loss')
ax1.plot(all_eval_losses, label='eval_loss')

ax2.plot(all_train_accuracy, label='train_accuracy')
ax2.plot(all_test_accuracy, label='eval_accuracy')

ax1.legend()
ax2.legend()
plt.show()
plt.clf()

# %%
asfdghywqdw
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-08571a103190> in <cell line: 0>()
# ----> 1 asfdghywqdw
#
# NameError: name 'asfdghywqdw' is not defined

# %%
# Define the Text Encoder
class TextEncoder(nn.Module):
    embed_dim: int = 128
    vocab_size: int = 10
    max_length: int = 77

    @nn.compact
    def __call__(self, x):
        # x shape: (batch, sequence_length)
        x = nn.Embed(self.vocab_size, self.embed_dim)(x)

        x = S6_Unet()(nn.RMSNorm()(x))

        # Transformer blocks
        for _ in range(6):
            x = nn.MultiHeadDotProductAttention(
                num_heads=8,
                qkv_features=self.embed_dim
            )(x)
            x = nn.LayerNorm()(x)

        # Projection to embedding dimension
        x = nn.Dense(self.embed_dim)(x[:, 0])  # Take CLS token
        return x

# %%
key = jax.random.PRNGKey(42)
# x = jnp.expand_dims(xb[0],axis=0)
x = jnp.ones((64,20), dtype=jnp.int64)

model = TextEncoder()

params = model.init(jax.random.PRNGKey(45),x)
print(params.keys())
n_params = sum(p.size for p in jax.tree_util.tree_leaves(params))

print(f"Total number of parameters: {n_params:_}")

output = model.apply(params, x)
print(output.shape)

# %%
params['params']['Embed_0']['embedding'].shape
